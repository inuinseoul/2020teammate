# %%
import pandas as pd
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import seaborn as sns
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
screening_center = pd.read_excel('data/선별진료소.xls')
assured_hospital = pd.read_excel('data/국민안심병원.xls')
time_pr = pd.read_csv('./data/TimeProvince.csv')
pat_info = pd.read_csv('./data/PatientInfo.csv')
time = pd.read_csv('./data/Time.csv')
weather = pd.read_csv('./data/Weather.csv')
region = pd.read_csv('./data/Region.csv')
time_age = pd.read_csv('./data/TimeAge.csv')
time_gndr = pd.read_csv('./data/TimeGender.csv')
policy = pd.read_csv('./data/Policy.csv')
pat_rte =  pd.read_csv('./data/PatientRoute.csv')
srch_trnd = pd.read_csv('./data/SearchTrend.csv')
case = pd.read_csv('./data/Case.csv')
seoul = pd.read_csv('./data/SeoulFloating.csv')

# %%
hospital_ratio = pat_rte[PatientRoute['type'] == 'hospital'].groupby('province')['patient_id'].count() / pat_rte.groupby('province')['patient_id'].count()
hospital_ratio = hospital_ratio.sort_values()

# %%
assured_hospital_count = assured_hospital.groupby('시도')['기준일'].count()
assured_hospital_count = assured_hospital_count.sort_values()
assured_hospital_count.index = ['Sejong', 'Jeju-do', 'Gwangju', 'Daejeon', 'Gangwon-do', 'Ulsan', 'Jeollabuk-do', 'Chungcheongbuk-do', 'Jeollanam-do', 'Chungcheongnam-do', 'Daegu', 'Gyeongsangbuk-do', 'Incheon', 'Gyeongsangnam-do', 'Busan', 'Seoul', 'Gyeonggi-do']
assured_hospital_count['Chungcheongnam-do'] += assured_hospital_count['Sejong']
assured_hospital_count = assured_hospital_count.drop(['Sejong'])

# %%
screening_center_count = screening_center.groupby('시도')['기준일'].value_counts()
screening_center_count = screening_center_count.sort_values()
screening_center_count.index = ['Sejong', 'Gwangju', 'Jeju-do', 'Ulsan', 'Daejeon', 'Daegu', 'Jeollabuk-do', 'Incheon', 'Chungcheongbuk-do', 'Chungcheongnam-do', 'Gangwon-do', 'Busan',
       'Gyeongsangbuk-do', 'Gyeongsangnam-do', 'Jeollanam-do', 'Seoul', 'Gyeonggi-do']
screening_center_count['Chungcheongnam-do'] += screening_center_count['Sejong']
screening_center_count = screening_center_count.drop(['Sejong'])

# %%
hospital_ratio= hospital_ratio.sort_index()
assured_hospital_count = assured_hospital_count.sort_index()
screening_center_count = screening_center_count.sort_index()

# %%
plt.figure(figsize=(10, 10))
plt.bar(hospital_ratio.index, hospital_ratio.values, color=['#F78181', '#F79F81', '#F7BE81', '#F5DA81', '#F3F781', '#D8F781', '#9FF781', '#81F79F', '#A9E2F3', '#A9E2F3', '#D0A9F5', '#F5A9F2', '#F781BE', '#FA5882', '#013ADF', '#848484'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.bar(assured_hospital_count.index, assured_hospital_count.values, color=['#F78181', '#F79F81', '#F7BE81', '#F5DA81', '#F3F781', '#D8F781', '#9FF781', '#81F79F', '#A9E2F3', '#A9E2F3', '#D0A9F5', '#F5A9F2', '#F781BE', '#FA5882', '#013ADF', '#848484'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.bar(screening_center_count.index, screening_center_count.values, color=['#F78181', '#F79F81', '#F7BE81', '#F5DA81', '#F3F781', '#D8F781', '#9FF781', '#81F79F', '#A9E2F3', '#A9E2F3', '#D0A9F5', '#F5A9F2', '#F781BE', '#FA5882', '#013ADF', '#848484'])
plt.xticks(rotation=90)
plt.show()
